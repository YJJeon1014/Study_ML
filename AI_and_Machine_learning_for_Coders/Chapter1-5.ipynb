# %% [markdown]
# <a href="https://colab.research.google.com/github/YeongJunJeon/Study_ML/blob/ml_study/AI_and_Machine_learning_for_Coders/Chapter1-5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![{E6AB70D1-6D31-4DA1-B08A-E34B7FF520FB}.png](data:image/png;base64,...)

# %% [markdown]
# 일반적인 프로그램 작성에서는 규칙을 지정한 후, 입력값에 따라서 출력 및 결과가 결정된다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 위처럼, 속도에 대한 규칙을 지정한 후, 속도에 따라서 상태를 결정하는데 이는 매우 간단하지만, 인간의 모든 행동을 규정하는 것은 거의 불가능하다.

# %%
# This is a code pane
import tensorflow as tf
#print(tf.__version__)

# %%
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

model = Sequential([Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=500)

print(model.predict([10.0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 216ms/step - loss: 54.1598
# Epoch 2/500
# 1/1 [==============================] - 0s 6ms/step - loss: 43.0201
# Epoch 3/500
# 1/1 [==============================] - 0s 7ms/step - loss: 34.2474
# Epoch 4/500
# 1/1 [==============================] - 0s 5ms/step - loss: 27.3373
# Epoch 5/500
# 1/1 [==============================] - 0s 5ms/step - loss: 21.8926
# Epoch 6/500
# 1/1 [==============================] - 0s 6ms/step - loss: 17.6012
# Epoch 7/500
# 1/1 [==============================] - 0s 7ms/step - loss: 14.2171
# Epoch 8/500
# 1/1 [==============================] - 0s 6ms/step - loss: 11.5471
# Epoch 9/500
# 1/1 [==============================] - 0s 11ms/step - loss: 9.4390
# Epoch 10/500
# 1/1 [==============================] - 0s 4ms/step - loss: 7.7732
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 6.4555
# Epoch 12/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.4118
# ...

# %%
print(model.predict([11.0]))
# Out:
# [[20.972538]]
